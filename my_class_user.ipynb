# %%
from my_class import MyClass

# %%
# csv loading is done in the init
pipeline = MyClass(dataset_path='data/CV_subset/', 
                   csv_path='data/Human_limbs_annotations.csv')

# %%
filenumber = 4
result_img = pipeline.remove_human_parts_with_visualization(filenumber)
# Out:
# IoU:  0.9247142359440582

# %% [markdown]
# ### with/without edge mask

# %%
pipeline = MyClass(dataset_path='data/CV_subset/', 
                   csv_path='data/Human_limbs_annotations.csv', with_edge_mask=False)
pipeline.mean_iou()
# Out:
# filenumber:  51  - filename:  manchette-elastiquee-plastique-opaque-blanc-20-x-40-cm-par-100.jpg
# Human Mask was empty, even though a body part was detected.
# filenumber:  46  - filename:  gants-nitrile-bleus-non-poudres-taille-xl-9-10-par-100.jpg
# Human Mask was empty, even though a body part was detected.
# filenumber:  45  - filename:  gants-nitrile-bleus-non-poudres-taille-s-6-7-par-100.jpg
# Human Mask was empty, even though a body part was detected.
# filenumber:  44  - filename:  gants-nitrile-bleus-non-poudres-taille-m-7-8-par-100.jpg
# Human Mask was empty, even though a body part was detected.
# filenumber:  43  - filename:  gants-nitrile-bleus-non-poudres-taille-l-8-9-par-100.jpg
# Human Mask was empty, even though a body part was detected.
# without counting non detected human masks, mean IoU is:  0.7047348927383303
# 0.6601314185143854

# %%
# csv loading is done in the init
pipeline = MyClass(dataset_path='data/CV_subset/', 
                   csv_path='data/Human_limbs_annotations.csv', with_edge_mask=True)
pipeline.mean_iou()
# Out:
# filenumber:  51  - filename:  manchette-elastiquee-plastique-opaque-blanc-20-x-40-cm-par-100.jpg
# Human Mask was empty, even though a body part was detected.
# filenumber:  46  - filename:  gants-nitrile-bleus-non-poudres-taille-xl-9-10-par-100.jpg
# Human Mask was empty, even though a body part was detected.
# filenumber:  45  - filename:  gants-nitrile-bleus-non-poudres-taille-s-6-7-par-100.jpg
# Human Mask was empty, even though a body part was detected.
# filenumber:  44  - filename:  gants-nitrile-bleus-non-poudres-taille-m-7-8-par-100.jpg
# Human Mask was empty, even though a body part was detected.
# filenumber:  43  - filename:  gants-nitrile-bleus-non-poudres-taille-l-8-9-par-100.jpg
# Human Mask was empty, even though a body part was detected.
# without counting non detected human masks, mean IoU is:  0.6552211006870332
# 0.6137514107701324

# %% [markdown]
# ### Visualisation

# %%
# Out:
# IoU:  0.9247142359440582
